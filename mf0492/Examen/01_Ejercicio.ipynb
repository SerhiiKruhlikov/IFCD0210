# %% [markdown]
# #### Crea una función python que valide una contraseña:
# La contraseña debe cumplir:
# * Mínimo 8 caracteres
# * Al menos una mayúscula
# * Al menos un número
# * Al menos un carácter especial
#
# Devuelve:
# * "Válida"
# * o el motivo del error

# %%
def validator_contrasena(password):
    # Creamos flags para cada condición
    isUppercase = False
    isNumber = False
    isSpecial = False
    
    # Comprobando la longitud
    if len(password) < 8:
        return "Error: Mínimo 8 caracteres"
    
    for char in password:
        if char.isupper():
            isUppercase = True
        elif char.isdigit():
            isNumber = True
        elif not char.isalnum():
            isSpecial = True
    
    if not isUppercase:
        return "Error: Al menos una mayúscula"
    
    if not isNumber:
        return "Error: Al menos un número"
    
    if not isSpecial:
        return "Error: Al menos un carácter especial"

    return "Válida"


print(validator_contrasena("test123"))
print(validator_contrasena("test123er"))
print(validator_contrasena("testSSSer"))
print(validator_contrasena("testSS34Ser"))
print(validator_contrasena("tesT123er!"))
# Out:
# Error: Mínimo 8 caracteres
# Error: Al menos una mayúscula
# Error: Al menos un número
# Error: Al menos un carácter especial
# Válida
