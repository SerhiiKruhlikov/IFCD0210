# %% [markdown]
# # Ejercicios diccionarios

# %% [markdown]
# 1. Escriba un programa que solicite repetidamente al usuario el nombre y el precio de los productos. <br>
# Almacene todos estos datos en un diccionario cuyas claves sean los nombres de los productos y cuyos valores sean los precios.<br>
# Terminará al introducir un producto vacío.<br>
# Se podrán introducir productos repetidos, pero solo se almacenarán una vez y se imprimirá el precio correspondiente o un mensaje si el producto no está en el diccionario.

# %%
productos = {}

while True:
    nombre = input("Dime el nombre del Producto")
    
    if nombre == '':
        break
        
    precio = input("Dime el precio")
    
    #Por si se quire guardar el primer valor introducido
    if not nombre in productos:
        productos[nombre] = float(precio)
    else:
        print(f'El producto {nombre} ya está en el diccionario')
    
    # productos[nombre] = precio
    
from pprint import pprint
pprint(productos)
# Out:
# {'pera': '4'}

# %% [markdown]
# 2. Usando el diccionario creado en el problema anterior, permita al usuario ingresar una cantidad en dólares e imprima todos los productos cuyo precio sea menor a esa cantidad.

# %%
productos = {
    'pera': 1.2,
    'tomate': 3.1,
    'uva': 3.23,
}

lista = [];

filtro = float(input("Dime el precio máximo"))

for k, v in productos.items():
    if v < filtro:
        print(lista.append(f"Product: {k}, Precio: {v}"))

print(lista)
# Out:
# None
# ['Product: pera, Precio: 1.2']

# %% [markdown]
# 3. Para este problema, cree un diccionario cuyas claves sean los nombres de los meses y cuyos valores sean el número de días de los meses correspondientes.
# - (a) Pida al usuario que ingrese el nombre de un mes y use el diccionario para indicarle cuántos días tiene el mes.
# - (b) Imprima todas las claves en orden alfabético.
# - (c) Imprima todos los meses de 31 días.
# - (d) Imprima los pares (clave-valor) ordenados por el número de días de cada mes.
# - (e) Modifique el programa de la parte (a) y el diccionario para que el usuario no tenga que saber cómo escribir el nombre del mes con exactitud. Es decir, solo tiene que escribir correctamente las tres primeras letras del nombre del mes.

# %%
import calendar
from datetime import datetime

current_year = datetime.now().year
days_per_month = {}

for month in range(1, 13):
    _, days_in_month = calendar.monthrange(current_year, month)
    month_name = calendar.month_name[month]
    days_per_month[month_name] = days_in_month
    

# a)
# mes = input("Dime el nombre del mes").capitalize()
# if mes in days_per_month:
#     print(f"El mes de {mes} tiene {days_per_month[mes]}")
# else:
#     print("Mes incorrecto")


# b)
# claves = list(days_per_month.keys())
# claves.sort()
# print(claves)
# print(sorted(days_per_month.keys()))


# c)
# lista_31 = []
# 
# for k, v in days_per_month.items():
#     if v == 31:
#         lista_31.append(k)
#         
# print(lista_31)


# d)
# lista = list(days_per_month.items())
# cambiar = True
# 
# while cambiar:
#     cambiar = False
#     for i in range(len(lista) - 1):
#         if lista[i][1] > lista[i + 1][1]:
#             cambiar = True
#             lista[i], lista[i + 1] = lista[i + 1], lista[i]
# 
# print(lista)

# e)
mes = input("Dime el nombre el mes").lower()
longitud = len(mes)

while longitud > 2:
    for k in days_per_month.keys():
        if mes == k[:longitud].lower():
            print(f"Para la consulta '{mes}', se ha encontrado el mes '{k}' con un número de días: {days_per_month[k]}.")
# Out:
#   Cell In[62], line 60
#     break
#     ^
# SyntaxError: 'break' outside loop

# %% [markdown]
# 4. Escriba un programa que utilice un diccionario que contenga diez nombres de usuario y contraseñas. <br>
# El programa debe solicitar al usuario que ingrese su nombre de usuario y contraseña. <br>
# - Si el nombre de usuario no está en el diccionario, el programa debe indicar que la persona no es un usuario válido del sistema. <br>
# - Si el nombre de usuario está en el diccionario, pero el usuario no ingresa la contraseña correcta, el programa debe indicar que la contraseña no es válida. <br>
# - Si la contraseña es correcta, el programa debe indicar al usuario que ya ha iniciado sesión en el sistema.

# %% [markdown]
# 5. Solicite repetidamente al usuario que ingrese el nombre de un equipo y cuántos partidos ganó y perdió el equipo. <br>
# Almacene esta información en un diccionario donde las claves sean los nombres de los equipos y los valores sean listas con el formato [victorias, derrotas].
# - (a) Usando el diccionario creado anteriormente, permita al usuario ingresar el nombre de un equipo e imprimir su porcentaje de victorias.
# - (b) Usando el diccionario, cree una lista cuyas entradas sean el número de victorias de cada equipo.
# - (c) Usando el diccionario, cree una lista de todos los equipos con una mayoría de victorias.

# %% [markdown]
# 6. Solicite repetidamente al usuario que ingrese los puntajes de los juegos en un formato como equipo1 puntaje1 - equipo2 puntaje2.<br>
# Almacene esta información en un diccionario donde las claves sean los nombres de los equipos y los valores sean listas con el formato [victorias, derrotas].

# %% [markdown]
# 7. Cree una lista de números de 5 × 5. <br>
# Luego, escriba un programa que cree un diccionario cuyas claves sean los números y cuyos valores sean las veces que aparece el número.<br> Luego, imprima los tres números más comunes.

# %% [markdown]
# 8. Construya un diccionario con las cartas de la baraja, cree un juego de cartas simple que reparta tres cartas a dos jugadores.
# El jugador con la carta más alta gana.
# En caso de empate, se compara la segunda carta más alta y, si es necesario, la tercera más alta.
# Si las tres cartas tienen el mismo valor, el juego es un empate.

# %%
jugadores = 2

# %% [markdown]
# 9. Utilizando el diccionario de cartas, reparta tres cartas. Determine lo siguiente:
# - (a) Si las tres cartas forman color (todas del mismo palo).
# - (b) Si hay un trío (todas del mismo valor).
# - (c) Si hay una pareja, pero no un trío.
# - (d) Si las tres cartas forman una escalera (todas en fila, como (2, 3, 4) o (10, Jota, Reina).

# %% [markdown]
# 10. El cifrado de sustitución reemplaza cada letra por una diferente. <br>
# Por ejemplo, cada a podría reemplazarse por una e, cada b por una a, etc. <br>
# Escriba un programa que solicite al usuario que ingrese dos cadenas. <br>
# Luego, determine si la segunda cadena podría ser una versión codificada de la primera con un cifrado de sustitución. <br>
# Por ejemplo, CXYZ no es una versión codificada de BOOK porque O se asignó a dos letras distintas.
# Asimismo, CXXK no es una versión codificada de BOOK porque K se asignó a sí misma. <br>
# Por otro lado, CXXZ sería una codificación de BOOK. <br>
# Este problema se puede resolver con o sin diccionario.

# %% [markdown]
# 11. Los diccionarios proporcionan una forma conveniente de almacenar datos estructurados. Aquí tienes un diccionario de ejemplo:<br>
# ```python
# d=[{ 'name ': 'Todd ', 'phone ': '555-1414 ', 'email ': 'todd@mail.net '},
# { 'name ': 'Helga ', 'phone ': '555-1618 ', 'email ': 'helga@mail.net '},
# { 'name ': 'Princess ', 'phone ': '555-3141 ', 'email ': ''},
# { 'name ': 'LJ ', 'phone ': '555-2718 ', 'email ': 'lj@mail.net '}]
# ```
# Escribe un programa que lea cualquier diccionario como este e imprima lo siguiente:
# - (a) Todos los usuarios cuyo número de teléfono termine en 8
# - (b) Todos los usuarios que no tengan una dirección de correo electrónico registrada

# %% [markdown]
# 15. (a) Escribe un programa que convierta números romanos en números ordinarios. <br>
# Aquí están las conversiones: <br>
# M = 1000, <br>
# D = 500, <br>
# C = 100, <br>
# L = 50, <br>
# X = 10, <br>
# V = 5, <br>
# I = 1. <br>
# No olvides que IV es 4 y XL es 40.<br>
# (b) Escribe un programa que convierta números ordinarios a números romanos.
