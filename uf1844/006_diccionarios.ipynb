# %% [markdown]
# Diccionarios

# %%
dic1 = {
    1: 'uno',
    2: 'dos',
    'nombre': 'paco',
    'apellido': 'lopez',
}
alumnos = [{
    'nombre': 'maría josé',
    'direccion': {
        'calle': 'sierpes',
        'numero': '1',
        'cp': '41001',
        'telefonos': [
            '123456789',
            '098765432',
        ]
    }
},
{
    'nombre': 'alejandro hidalgo',
    'direccion': {
        'calle': 'sierpes',
        'numero': '1',
        'cp': '41001',
        'telefonos': [
            '123456789',
            '098765432',
        ]
    }
}]

# %%
alumno1 = {
    'nombre': 'alejandro hidalgo',
    'direccion': {
        'calle': 'sierpes',
        'numero': '1',
        'cp': '41001',
        'telefonos': [
            '123456789',
            '098765432',
        ]
    }
}

alumno1['nombre']
alumno1['direccion']['telefonos'][0]

direccion = alumno1['direccion']
# Out:
# '123456789'

# %%
otro = {
    'p1': 0,    
}

otro['p2'] = {
    'nombre': 'alejandro hidalgo',
    'direccion': {
        'calle': 'sierpes',
        'numero': '1',
        'cp': '41001',
        'telefonos': [
            '123456789',
            '098765432',
        ]
    }
}

otro

otro.get('p2')

otro.get('p3', 'No hay nada')
# Out:
# 'No hay nada'

# %%
lorem = 'lorem ipsum dolor sit amet consecttetur'

letras = {}

# for letra in lorem:
#     if letra in letras:
#         letras[letra] += 1
#     else:
#         letras[letra] = 1

for letra in lorem:
    if letras.get(letra) is not None:
        letras[letra] += 1
    else:
        letras[letra] = 1

# for letra in lorem:
#     if letras.get(letra, False):
#         letras[letra] += 1
#     else:
#         letras[letra] = 1
    
from pprint import pprint
pprint(letras)
# Out:
# {' ': 5,
#  'a': 1,
#  'c': 2,
#  'd': 1,
#  'e': 4,
#  'i': 2,
#  'l': 2,
#  'm': 3,
#  'n': 1,
#  'o': 4,
#  'p': 1,
#  'r': 3,
#  's': 3,
#  't': 5,
#  'u': 2}

# %%
claves = letras.keys()
valores = letras.values()

print(claves)
print(valores)

elementos = letras.items()

print(elementos) 

for c in elementos:
    print(f'Clave: {c[0]}, Valor: {c[1]}')
# Out:
# dict_keys(['l', 'o', 'r', 'e', 'm', ' ', 'i', 'p', 's', 'u', 'd', 't', 'a', 'c', 'n'])
# dict_values([2, 4, 3, 4, 3, 5, 2, 1, 3, 2, 1, 5, 1, 2, 1])
# dict_items([('l', 2), ('o', 4), ('r', 3), ('e', 4), ('m', 3), (' ', 5), ('i', 2), ('p', 1), ('s', 3), ('u', 2), ('d', 1), ('t', 5), ('a', 1), ('c', 2), ('n', 1)])
# Clave: l, Valor: 2
# Clave: o, Valor: 4
# Clave: r, Valor: 3
# Clave: e, Valor: 4
# Clave: m, Valor: 3
# Clave:  , Valor: 5
# Clave: i, Valor: 2
# Clave: p, Valor: 1
# Clave: s, Valor: 3
# Clave: u, Valor: 2
# Clave: d, Valor: 1
# Clave: t, Valor: 5
# Clave: a, Valor: 1
# Clave: c, Valor: 2
# Clave: n, Valor: 1

# %%
otro = {
    1: 'a',
    2: 'b',
    3: 'c',
    4: 'd',
}

keys = otro.keys()
values = otro.values()

print(keys)
print(values)

nuevo = {}

# for o in otro.items():
#     nuevo[o[1]] = o[0]
    

for k, v in otro.items():
    nuevo[v] = k

print(nuevo)
# Out:
# dict_keys([1, 2, 3, 4])
# dict_values(['a', 'b', 'c', 'd'])
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
type(None)
# Out:
# NoneType

# %%
type(False)
# Out:
# bool
